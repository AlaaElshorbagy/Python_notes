# %% [markdown]
# <a href="https://colab.research.google.com/github/AlaaElshorbagy/Python_notes/blob/main/Mynotes/Recursion22_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Steps:
#
# 1.   Find the simplest possible input (Base Case).
# 2.   Play around with examples and visualize!.
# 3.   Relate Hard cases to simpler cases.
# 4.   Generalize the pattern.

# %% [markdown]
# ## Example 0: write a factorial function in Python using recursion.

# %%
#soln1: interations
def comp_factorial(n):
  fn =1
  if n>1:
    for i in range(2,n+1):
      fn = fn*i
  return fn

# %%
comp_factorial(4)
# Out:
# 24

# %%
#soln 2: Recursion
def comp_factorial(n):
  if n == 0:
    return 1
  return n*comp_factorial(n-1)

# %%
comp_factorial(4)
# Out:
# 24

# %% [markdown]
# ## Example 1:
#
# Write a recursive function that given an input n sums all nonnegative integers up to n.

# %%
# soln1: Mathematical
def sum(n):
  return n*(n+1)/2

# %%
#soln2: Iteration
def sum(n):
  result =0
  for i in range(n+1):
    result +=i
  return result

# %%
sum(4)
# Out:
# 10

# %%
# soln3: Recursion
def sum(n):
  if n ==0:
    return 0
  return n+sum(n-1)

# %%
sum(4)
# Out:
# 10

# %% [markdown]
# ## Example 2:
#
# Write a function that takes two input n and m and outputs the number of unique paths from top left corner to bottom right corner of a nxm grid. Constraints: you can only move down or right.

# %% [markdown]
# ![Screenshot 2023-08-22 at 3.03.41 PM.png](data:image/png;base64,...)

# %%
def grid_paths(n,m):
  if n ==1 or m==1:
    return 1
  else:
    return grid_paths(n,m-1)+grid_paths(n-1,m)

# %%
grid_paths(2,3)
# Out:
# 3

# %% [markdown]
# ## Example 3:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def count_partitions(n,m):
  #base case
  if n ==0 :
    return 1
  elif m == 0 or n <0:
    return 0
  #generalized
  return count_partitions(n-m,m) +count_partitions(n,m-1)

# %%
count_partitions(9,5)
# Out:
# 23
